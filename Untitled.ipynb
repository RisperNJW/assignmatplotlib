# %%
import pandas as pd
data = pd.read_csv("kenya_primary_schools.csv")
data.head()
# Out:
#        X     Y    FID          Name_of_Sc          Level_  Status  \
# 0  36.14  0.27  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC
# 1  36.17  0.26  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC
# 2  36.18  0.24  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC
# 3  36.19  0.21  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 4  37.70 -0.88  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC
#
#                SchSponsor  Type1     Type2     Type3  ...  OthersF  \
# 0  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 1  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 2               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 3               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 4               COMMUNITY  MIXED  DAY ONLY  ORDINARY  ...      0.0
#
#    NoTeaching  NonTeachin     Province  District  Division  Location  \
# 0         0.0         0.0  RIFT VALLEY  KOIBATEK  KISANANA   MOGOTIO
# ...

# %%
data.isnull().sum()
data_clean = data.dropna()
data_clean.isnull().sum().sum()
# Out:
# 0

# %%
data_clean.describe()
data_clean.groupby('Province')['TotalEnrol'].mean().sort_values(ascending=False)
# Out:
# Province
# WESTERN        483.599469
# COAST          389.240402
# NYANZA         332.000000
# RIFT VALLEY    307.037898
# CENTRAL        292.856560
# EASTERN        283.639934
# Central         58.000000
# NAIROBI         10.000000
# Name: TotalEnrol, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(style="whitegrid")

data_clean['Index'] = range(len(data_clean))
sns.lineplot(data=data_clean, x='Index', y='TotalEnrol')
plt.title('Enrollment Trend')
plt.show()

# %%
data_clean.groupby('Province')['TotalEnrol'].mean().sort_values().plot(kind='barh', color= ["red", "green", "yellow", "pink", "brown", "orange", "blue","black"])
plt.title('The Average Enrollment by Province')
plt.xlabel('Enrollment')
plt.show()

# %%
sns.histplot(data_clean['PupilTeach'], bins=40, kde=True)
plt.title('Distribution of Pupil-Teacher Ratio')
plt.show()

# %%
sns.scatterplot(data=data_clean, x='NoTeaching', y='TotalEnrol')
plt.title('Enrollment vs. Teaching Staff')
plt.show()

# %%
data_clean.to_csv('kenya_primary_schools_clean.csv', index=False)
